# %%
import pandas as pd

# %%
dados = pd.read_csv('dados_experimentos.csv')
#na aula ele criou uma variável com o link fornecido pelo próprio github e forneceu a esse comando que usei essa url
#só q na url o arquivo ta zipado, então ele deu o parâmetro compression = 'zip'

# %%
dados
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
#cada linha é uma culura de célula segunda a Vanessa Leiko

# %%
#Como cientista de dados a primeira coisa que eu quero fazer quando pego um problema que eu não conheço é saber

# %%
#que tipo de informação eu vou estar trabalhando

# %%
#Por exemplo, esperamos que o id seja um indentificador único para cada parada

# %%
#Geralmente plotamos só o começo da tabela

# %%
dados.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
#mas ai perdemos a informação do tamanho da tabela, contudo, podemos recuperar com o shape:

# %%
dados.shape
# Out:
# (23814, 877)

# %%
#vamos começar com a coluna tratamento: que será uma série, e lembrando, a tabela é um dataframe

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
#queremos ver os valores únicos:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#Interessante, temos só esses 2 valores, e a vanessa disse q o com controle é um grupo que está submetido a cond
# normais a fim de comparação para ver a influência da variável que estamos testando!

# %%
#prox coluna
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
#tem uma cacetada, então não tem como tirar tantas conclusões, contudo, a van disse que aqui os nomes foram
#propositalmente escondidos para não termos viezes por sabermos qual droga estamos testando e o que esperamos dela

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
#Segundo a Van esse g se refere a gene, e esses valores são a expressão desse gene em relação a exposição a droga

# %%
#Sendo apresentado ao background de biologia da situação o Thiago já formulou a hipótese de que os valores
#provavelmente estão normalizados =]

# %%
#Queremos agora uma análise mais quantitativa
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
#Desafio 1: por que essa dispariedade entre o número de com droga e controle?
#Desafio 2: Plotar as 5 últimas linhas da tabela
#Desafio 3: Proporção das classes tratamento
#Desafio 4: Quantos tipos de drogas foram investigados?

# %% [markdown]
# A dispariedade entre o número de testes com droga e com controle tem origem no fato de que, como o grupo controle já é bem estudado e temos uma margem de resultados já esperados, podemos realizar uma menor quantidade de testes controle.

# %%
#Desafio 2:
dados[23809:]
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %%
dados['tratamento'].value_counts(normalize = True) # =]
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# d70cdde82       1
# 18a406358       1
# b01cf573a       1
# ed64cad3a       1
# 758c4ac3d       1
# Name: droga, Length: 3289, dtype: int64

# %%
#3289 drogas :o

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
#vamos fazer gráficos de pizza para vizualizar melhor agora:

# %%
dados['tratamento'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='tratamento'>

# %%
dados['tempo'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='tempo'>

# %%
#Esses gráficos q tem nome de comida geralmente não são utilizados rs

# %%
#Vamos fazer outro gráfico simples mas q é útil
dados['tempo'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Guilherme comentou que, como os valores parecem estar normalizados, ele olharia em quais linhas esses valores
#estão acima de 0

# %%
g0maior0 = dados[dados['g-0'] > 0]
g0maior0.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 6  id_001bd861f  com_droga     24   D2  746ca1f5a  2.0440  1.7000 -1.5390
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 6  5.9440 -2.1670  ...  0.1855  1.1720  0.8325  0.6486  0.8090  1.5880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
#Desafio 5: Procurar na documentação o método query(pandas)

# %%
#no caso poderiamos ter feito a operação previa da seguinte forma:
dados.query('`g-0` > 0') #só vem
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 6      id_001bd861f     com_droga     24   D2  746ca1f5a  2.0440  1.7000
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# ...             ...           ...    ...  ...        ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23808  id_fff8c2444     com_droga     72   D1  6c3a459be  0.1608 -1.0500
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
#Desafio 6: Colocar título no gráfico:

# %%
dados['tempo'].value_counts().plot.bar(title = 'Time')
# Out:
# <AxesSubplot:title={'center':'Time'}>

# %%
#Desafio 7: Renomear as colunas tirando o hífen.
#uma só:
newdf = dados.rename(columns={'g-0':'g0'})

# %%
#Todas
colunas = []
dados2 = dados
for i in dados2.columns:
    i = i.replace('-', '')
    colunas.append(i)
dados2.columns = colunas

# %%
dados2 #SOU UM GÊNIO
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
#desafio 8: Resumo do que você aprendeu
